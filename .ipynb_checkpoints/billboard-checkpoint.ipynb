# %%
from bs4 import BeautifulSoup
import requests

# %%
# Define dict
songs = {}

# %%
# Billboard hot 100 page
url = "http://www.billboard.com/charts/hot-100"

# %%
def get_ranks(url, i):
    global songs
    # Get page
    r = requests.get(url)
    # Cook soup
    soup = BeautifulSoup(r.text, 'html.parser')
    # Extract ranks
    for song in soup.find_all(class_='chart-row__main-display'):
        song_rank   = song.find(class_='chart-row__current-week').string
        song_title  = song.find(class_='chart-row__song').string
        song_artist = song.find(class_='chart-row__artist').string.strip()
        song_name   = song_title + " : " + song_artist
        song_name   = str(song_name)
        if songs.get(song_name, 'hrily') is 'hrily':
            songs[song_name] = [[], []]
        songs[song_name][0].append(i)
        songs[song_name][1].append(int(song_rank))
    return soup

# %%
def print_ranks():
    global songs
    for name in songs.keys():
        print name + " = " + str(songs[name])

# %%
def get_previous_week_link(soup):
    link = soup.find(title="Previous Week")
    return link['href']

# %%
def get_last_n_ranks(n=1):
    url = "http://www.billboard.com/charts/hot-100"
    for i in range(n):
        soup = get_ranks(url, n-i)
        url  = "http://www.billboard.com" + get_previous_week_link(soup)

# %%
get_last_n_ranks(6)

# %%
print_ranks()
# Out:
# You're Welcome : Dwayne Johnson = [[2, 1], [91, 81]]
# Love On The Brain : Rihanna = [[6, 5, 4, 3, 2, 1], [8, 13, 14, 14, 17, 19]]
# Redbone : Childish Gambino = [[6, 5, 4, 3, 2, 1], [99, 98, 94, 76, 63, 72]]
# Deja Vu : J. Cole = [[6, 5, 4, 3, 2, 1], [50, 51, 47, 46, 48, 48]]
# Dirt On My Boots : Jon Pardi = [[6, 5, 4, 3, 2, 1], [39, 46, 43, 44, 57, 58]]
# Million Reasons : Lady Gaga = [[6, 5, 3, 1], [18, 4, 97, 96]]
# Starboy : The Weeknd Featuring Daft Punk = [[6, 5, 4, 3, 2, 1], [14, 12, 7, 8, 5, 4]]
# Love Me Now : John Legend = [[6, 5, 4, 3, 2, 1], [51, 45, 35, 33, 31, 30]]
# You Was Right : Lil Uzi Vert = [[2, 1], [46, 40]]
# Halfway Off The Balcony : Big Sean = [[5], [74]]
# Let Me Love You : DJ Snake Featuring Justin Bieber = [[6, 5, 4, 3, 2, 1], [28, 20, 18, 16, 16, 14]]
# Sneakin' : Drake Featuring 21 Savage = [[3, 2, 1], [95, 73, 69]]
# Not Nice : PARTYNEXTDOOR = [[6, 5, 4, 3, 2], [83, 82, 83, 83, 95]]
# Guys My Age : Hey Violet = [[6, 5, 4, 3], [68, 69, 87, 84]]
# No Heart : 21 Savage & Metro Boomin = [[6, 5, 4, 3, 2, 1], [82, 81, 73, 61, 50, 46]]
# How Far I'll Go : Alessia Cara = [[6, 5, 4, 3, 2, 1], [91, 83, 77, 68, 56, 59]]
# Parachute : Chris Stapleton = [[2, 1], [90, 79]]
# Get Right Witcha : Migos = [[4], [72]]
# Better Man : Little Big Town = [[6, 5, 4, 3, 2, 1], [35, 40, 34, 35, 41, 43]]
# All Time Low : Jon Bellion = [[6, 5, 4, 3, 2, 1], [26, 24, 20, 19, 22, 24]]
# Don't Wanna Know : Maroon 5 Featuring Kendrick Lamar = [[6, 5, 4, 3, 2, 1], [17, 9, 6, 7, 9, 8]]
# Play That Song : Train = [[6, 5, 4, 3, 2, 1], [59, 59, 41, 60, 69, 68]]
# Bad Romance : Lady Gaga = [[5], [50]]
# Any Ol' Barstool : Jason Aldean = [[6, 5, 4, 3], [76, 84, 95, 93]]
# Despacito : Luis Fonsi Featuring Daddy Yankee = [[6, 5, 4, 3, 2], [55, 61, 61, 77, 88]]
# Not Afraid Anymore : Halsey = [[2], [77]]
# Owe Me : Big Sean = [[5], [86]]
# A Guy With A Girl : Blake Shelton = [[6, 5, 4, 3, 2, 1], [69, 64, 52, 42, 51, 53]]
# If The Boot Fits : Granger Smith = [[4, 3, 1], [84, 80, 100]]
# Fake Love : Drake = [[6, 5, 4, 3, 2, 1], [12, 11, 8, 9, 11, 11]]
# Yeah Boy : Kelsea Ballerini = [[6], [94]]
# Make Me (Cry) : Noah Cyrus Featuring Labrinth = [[6, 5, 4, 3, 2, 1], [46, 47, 46, 57, 62, 66]]
# Scars To Your Beautiful : Alessia Cara = [[6, 5, 4, 3, 2, 1], [15, 8, 10, 10, 13, 13]]
# Kelly Price : Migos Featuring Travis Scott = [[5, 4], [100, 58]]
# Cold : Maroon 5 Featuring Future = [[6], [42]]
# Running Back : Wale Featuring Lil Wayne = [[3], [100]]
# Treat You Better : Shawn Mendes = [[6, 5, 4, 3, 2, 1], [36, 36, 32, 28, 26, 26]]
# All We Know : The Chainsmokers Featuring Phoebe Ryan = [[2, 1], [93, 92]]
# Blue Ain't Your Color : Keith Urban = [[4, 3, 2, 1], [42, 36, 35, 29]]
# Chantaje : Shakira Featuring Maluma = [[6, 5, 4, 3, 2, 1], [78, 67, 65, 59, 52, 54]]
# Beibs In The Trap : Travis Scott = [[2, 1], [97, 90]]
# Run Up : Major Lazer Featuring PARTYNEXTDOOR & Nicki Minaj = [[4], [66]]
# Rockabye : Clean Bandit Featuring Sean Paul & Anne-Marie = [[6, 5, 4, 3, 2, 1], [22, 23, 24, 32, 38, 51]]
# Goosebumps : Travis Scott = [[6, 5, 4, 3, 2, 1], [61, 65, 67, 51, 71, 73]]
# Juju On That Beat (TZ Anthem) : Zay Hilfigerrr & Zayion McCall = [[6, 5, 4, 3, 2, 1], [48, 42, 33, 30, 18, 17]]
# Cheap Thrills : Sia Featuring Sean Paul = [[5, 4, 3, 2, 1], [32, 30, 27, 27, 27]]
# I Got You : Bebe Rexha = [[6, 5, 4, 3, 2, 1], [43, 56, 59, 56, 53, 63]]
# 24K Magic : Bruno Mars = [[6, 5, 4, 3, 2, 1], [13, 15, 12, 11, 10, 7]]
# The Greatest : Sia Featuring Kendrick Lamar = [[5, 4, 3, 2, 1], [49, 40, 38, 39, 35]]
# Fast : Luke Bryan = [[6, 5, 4, 3], [72, 80, 86, 81]]
# Sleep Without You : Brett Young = [[1], [75]]
# I Hate U I Love U : gnash Featuring Olivia O'Brien = [[1], [41]]
# In Case You Didn't Know : Brett Young = [[6, 5], [75, 94]]
# Just Hold On : Steve Aoki & Louis Tomlinson = [[2, 1], [96, 99]]
# Love On The Weekend : John Mayer = [[3], [91]]
# Helium : Sia = [[6], [71]]
# Swang : Rae Sremmurd = [[6, 5, 4, 3, 2, 1], [57, 77, 76, 75, 61, 64]]
# Don't Let Me Down : The Chainsmokers Featuring Daya = [[5, 4, 3, 2, 1], [44, 36, 34, 33, 32]]
# Way Down We Go : Kaleo = [[6, 5, 4, 3, 2, 1], [81, 71, 63, 54, 85, 91]]
# No Favors : Big Sean Featuring Eminem = [[6, 5], [63, 22]]
# Mercy : Shawn Mendes = [[6, 5, 4, 3, 2, 1], [19, 19, 21, 21, 25, 23]]
# OTW : DJ Luke Nasty = [[5, 4, 3, 2, 1], [96, 92, 73, 72, 71]]
# Bounce Back : Big Sean = [[6, 5, 4, 3, 2, 1], [10, 6, 15, 15, 15, 16]]
# Timeless : A Boogie Wit da Hoodie Featuring DJ SPINKING = [[2, 1], [86, 88]]
# Say It : Flume Featuring Tove Lo = [[3, 2], [98, 94]]
# I'm Better : Missy Elliott Featuring Lamb = [[4], [71]]
# Scared To Be Lonely : Martin Garrix & Dua Lipa = [[6, 4], [100, 88]]
# Party : Chris Brown Featuring Usher & Gucci Mane = [[6, 5, 4, 3, 2, 1], [41, 48, 44, 40, 45, 45]]
# Seein' Red : Dustin Lynch = [[6, 5, 4, 3, 2, 1], [65, 55, 56, 55, 66, 65]]
# Now & Later : Sage The Gemini = [[5], [93]]
# Alone : Marshmello = [[4, 3, 2, 1], [98, 89, 60, 60]]
# Bom Bidi Bom : Nick Jonas & Nicki Minaj = [[6], [54]]
# Broccoli : D.R.A.M. Featuring Lil Yachty = [[6, 5, 4, 3, 2, 1], [37, 35, 31, 25, 21, 20]]
# Sacrifices : Big Sean Featuring Migos = [[5], [70]]
# My Sh*t : A Boogie Wit da Hoodie = [[2], [100]]
# Issues : Julia Michaels = [[6, 5, 4, 3], [34, 41, 64, 87]]
# Song For Another Time : Old Dominion = [[3, 2, 1], [96, 83, 76]]
# Congratulations : Post Malone Featuring Quavo = [[6, 5, 4, 3, 2, 1], [33, 39, 39, 58, 81, 85]]
# OOOUUU : Young M.A = [[1], [39]]
# Rolex : Ayo & Teo = [[6], [87]]
# Chill Bill : Rob $tone Featuring J. Davi$ & Spooks = [[3, 2, 1], [43, 40, 37]]
# Drinkin' Too Much : Sam Hunt = [[1], [89]]
# Cash Me Outside (#CashMeOutside) : DJ Suede The Remix God = [[6], [88]]
# Everything 1K : Kodak Black = [[6], [84]]
# Black Beatles : Rae Sremmurd Featuring Gucci Mane = [[6, 5, 4, 3, 2, 1], [16, 14, 9, 6, 3, 3]]
# Today : Brad Paisley = [[6, 5, 4, 3, 2, 1], [67, 75, 81, 74, 92, 95]]
# Road Less Traveled : Lauren Alaina = [[6, 5, 4, 3], [86, 90, 80, 86]]
# My Old Man : Zac Brown Band = [[5], [68]]
# Body Like A Back Road : Sam Hunt = [[6, 5, 4], [27, 21, 38]]
# Closer : The Chainsmokers Featuring Halsey = [[6, 5, 4, 3, 2, 1], [5, 7, 5, 3, 4, 5]]
# Black : Dierks Bentley = [[6, 4, 3, 2], [92, 97, 90, 98]]
# Castle On The Hill : Ed Sheeran = [[6, 5, 4, 3, 2, 1], [52, 62, 50, 39, 28, 6]]
# What They Want : Russ = [[1], [98]]
# Used To This : Future Featuring Drake = [[6, 5, 4, 3, 2, 1], [60, 57, 54, 47, 49, 50]]
# Heroe Favorito : Romeo Santos = [[6], [77]]
# El Amante : Nicky Jam = [[6, 4], [98, 99]]
# Red Opps : 21 Savage = [[2, 1], [78, 74]]
# Cold Water : Major Lazer Featuring Justin Bieber & MO = [[3, 2, 1], [48, 42, 38]]
# I Don't : Mariah Carey Featuring YG = [[5], [89]]
# Dirty Laundry : Carrie Underwood = [[4, 3, 2, 1], [90, 66, 58, 49]]
# Selfish : PnB Rock = [[6, 5, 4, 3, 2, 1], [89, 85, 78, 67, 59, 61]]
# Light : Big Sean Featuring Jeremih = [[5], [97]]
# Kill A Word : Eric Church Featuring Rhiannon Giddens = [[6, 5, 4, 3, 2, 1], [73, 78, 79, 71, 74, 80]]
# The Fighter : Keith Urban Featuring Carrie Underwood = [[6], [53]]
# Water Under The Bridge : Adele = [[6, 5, 4, 3, 2, 1], [31, 30, 28, 26, 34, 33]]
# Think A Little Less : Michael Ray = [[6, 5, 4, 3, 2, 1], [56, 63, 68, 62, 76, 82]]
# Both : Gucci Mane Featuring Drake = [[6, 5, 4, 3, 2, 1], [49, 53, 51, 49, 44, 44]]
# Location : Khalid = [[6, 5, 4, 3, 2, 1], [44, 52, 60, 64, 70, 77]]
# The Weekend : Brantley Gilbert = [[6, 5, 4, 3, 2, 1], [80, 79, 69, 79, 89, 93]]
# It Ain't Me : Kygo x Selena Gomez = [[6], [93]]
# Look At Me! : XXXTENTACION = [[6, 5], [74, 95]]
# Call Casting : Migos = [[4], [62]]
# Sex With Me : Rihanna = [[6, 4, 3, 2, 1], [95, 96, 85, 87, 86]]
# Paris : The Chainsmokers = [[6, 5, 4, 3, 2], [11, 10, 11, 13, 7]]
# HandClap : Fitz And The Tantrums = [[5, 4, 3, 2, 1], [54, 53, 53, 54, 55]]
# Star Of The Show : Thomas Rhett = [[6, 5, 4, 3, 2, 1], [64, 58, 45, 45, 55, 56]]
# Believer : Imagine Dragons = [[6, 5], [66, 43]]
# That's What I Like : Bruno Mars = [[6, 5, 4, 3], [7, 37, 57, 82]]
# Bad Things : Machine Gun Kelly x Camila Cabello = [[6, 5, 4, 3, 2, 1], [6, 5, 4, 4, 6, 10]]
# Say You Won't Let Go : James Arthur = [[6, 5, 4, 3, 2, 1], [23, 27, 29, 31, 30, 31]]
# Side To Side : Ariana Grande Featuring Nicki Minaj = [[6, 5, 4, 3, 2, 1], [24, 18, 13, 12, 12, 9]]
# I Don't Wanna Live Forever (Fifty Shades Darker) : Zayn / Taylor Swift = [[6, 5, 4, 3, 2, 1], [2, 3, 3, 5, 8, 12]]
# Hurricane : Luke Combs = [[6], [96]]
# Immortal : J. Cole = [[1], [97]]
# Good Drank : 2 Chainz x Gucci Mane x Quavo = [[3], [92]]
# Bad And Boujee : Migos Featuring Lil Uzi Vert = [[6, 5, 4, 3, 2, 1], [3, 2, 2, 1, 1, 2]]
# I Feel It Coming : The Weeknd Featuring Daft Punk = [[6, 5, 4, 3, 2, 1], [9, 16, 16, 18, 19, 22]]
# Moves : Big Sean = [[6, 5, 4, 3, 2, 1], [45, 38, 74, 72, 65, 62]]
# Some Kind Of Drug : G-Eazy Featuring Marc E. Bassy = [[6, 5, 4], [97, 99, 100]]
# Slippery : Migos Featuring Gucci Mane = [[6, 5, 4], [79, 73, 48]]
# Heathens : twenty one pilots = [[6, 5, 4, 3, 2, 1], [32, 29, 23, 22, 20, 18]]
# Culture : Migos Featuring DJ Khaled = [[4], [93]]
# May We All : Florida Georgia Line Featuring Tim McGraw = [[1], [52]]
# Shining : DJ Khaled Featuring Beyonce & JAY Z = [[6], [62]]
# This Town : Niall Horan = [[6, 5, 4, 3, 2, 1], [38, 33, 25, 24, 29, 28]]
# T-Shirt : Migos = [[6, 5, 4, 3, 2], [29, 26, 19, 37, 43]]
# How Far I'll Go : Auli'i Cravalho = [[5, 4, 3, 2, 1], [92, 75, 65, 67, 67]]
# Caroline : Amine = [[6, 5, 4, 3, 2, 1], [21, 17, 17, 17, 14, 15]]
# Beauty And The Beast : Ariana Grande & John Legend = [[5], [87]]
# Down : Marian Hill = [[6, 5, 4, 3, 2], [30, 31, 37, 52, 99]]
# Everyday : Ariana Grande Featuring Future = [[6], [85]]
# In The Name Of Love : Martin Garrix & Bebe Rexha = [[2, 1], [47, 34]]
# Sober Saturday Night : Chris Young Featuring Vince Gill = [[6, 5, 4, 3, 2, 1], [47, 66, 70, 63, 75, 83]]
# Call On Me : Starley = [[6, 5, 4, 3, 2, 1], [70, 72, 82, 88, 79, 94]]
# Dancing On My Own : Calum Scott = [[3], [94]]
# Shape Of You : Ed Sheeran = [[6, 5, 4, 3, 2, 1], [1, 1, 1, 2, 2, 1]]
# Starving : Hailee Steinfeld & Grey Featuring Zedd = [[6, 5, 4, 3, 2, 1], [40, 34, 26, 20, 23, 21]]
# Party Monster : The Weeknd = [[6, 5, 4, 3, 2, 1], [58, 60, 55, 50, 36, 47]]
# Wanna Be That Song : Brett Eldredge = [[6, 5, 4, 3, 2, 1], [90, 88, 85, 69, 64, 57]]
# Fresh Eyes : Andy Grammer = [[4, 3, 2, 1], [91, 70, 68, 84]]
# iSpy : KYLE Featuring Lil Yachty = [[6, 5, 4, 3, 2, 1], [20, 28, 27, 29, 32, 42]]
# Jump Out The Window : Big Sean = [[5], [76]]
# Neighbors : J. Cole = [[2, 1], [84, 70]]
# X : 21 Savage & Metro Boomin Featuring Future = [[4, 3, 2, 1], [49, 41, 37, 36]]
# Chained To The Rhythm : Katy Perry Featuring Skip Marley = [[6], [4]]
# 80s Mercedes : Maren Morris = [[5, 4, 3, 2, 1], [91, 89, 78, 82, 78]]
# Can't Stop The Feeling! : Justin Timberlake = [[6, 5, 4, 3, 2, 1], [25, 25, 22, 23, 24, 25]]
# Water : Ugly God = [[3, 2, 1], [99, 80, 87]]

# %%
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
import math

def exponential_fit(x, a, b, c):
    return a*np.exp(-b*x) + c

nCorrect = 0
nCompute = 0

for name in songs.keys():
    if len(songs[name][0])<4:
        continue
    x = songs[name][0]
    y = songs[name][1]
#     print x, y
    x = x[1:]
    y = y[1:]
#     print x, y
    x = np.array(x)
    y = np.array(y)
    x = x[::-1]
    y = y[::-1]
#     print x, y
    try:
        fitting_parameters, covariance = curve_fit(exponential_fit, x, y)
        a, b, c = fitting_parameters

        next_y_correct = songs[name][1][-1]

        next_x = 6
        next_y = exponential_fit(next_x, a, b, c)


        if next_y_correct == math.floor(next_y) or next_y_correct == math.floor(next_y+1):
            nCorrect = nCorrect + 1
        
        print next_y_correct, next_y
        nCompute = nCompute + 1
    except:
        print "Prediction failed for "+name

print nCorrect

#     plt.plot(y)
#     plt.plot(np.append(y, next_y), 'ro')
#     plt.show()
# Out:
# 19 12.5672775266
# 72 80.6000000773
# 48 47.9999999937
# 58 42.4254841721
# Prediction failed for Million Reasons : Lady Gaga
# 4 7.1999999978
# 30 34.8000000428
# 14 16.8
# 95 85.7499999974
# Prediction failed for Guys My Age : Hey Violet
# 46 62.2
# 59 68.6000000155
# 43 36.5201057026
# 24 21.1506784468
# 8 7.53385112194
# Prediction failed for Play That Song : Train
# Prediction failed for Any Ol' Barstool : Jason Aldean
# 88 55.6529799382
# 53 52.4000000259
# 11 9.09994062586
# 66 40.8669564019
# Prediction failed for Scars To Your Beautiful : Alessia Cara
# 26 29.6000000191
# Prediction failed for Blue Ain't Your Color : Keith Urban
# 54 59.4
# 51 20.3393254465
# 73 62.202660305
# 17 28.0000000459
# 27 27.7499999883
# 63 57.4
# Prediction failed for 24K Magic : Bruno Mars
# Prediction failed for The Greatest : Sia Featuring Kendrick Lamar
# 81 81.3338079608
# 64 70.6
# 32 33.75
# Prediction failed for Way Down We Go : Kaleo
# Prediction failed for Mercy : Shawn Mendes
# 71 77.0000000458
# Prediction failed for Bounce Back : Big Sean
# 45 44.4
# Prediction failed for Seein' Red : Dustin Lynch
# 60 69.6666667324
# 20 26.3999999693
# Prediction failed for Issues : Julia Michaels
# 85 24.3713944873
# Prediction failed for Black Beatles : Rae Sremmurd Featuring Gucci Mane
# 95 73.7791927578
# 86 85.3333332973
# 5 4.79999999371
# 98 95.0000000205
# 6 36.9999999278
# 50 51.3999999971
# 49 57.6666666642
# 61 69.9999999842
# 80 76.3999999804
# 33 28.0993293327
# Prediction failed for Think A Little Less : Michael Ray
# 44 48.200000001
# Prediction failed for Location : Khalid
# Prediction failed for The Weekend : Brantley Gilbert
# 86 88.4999999838
# 7 11.9997938956
# Prediction failed for HandClap : Fitz And The Tantrums
# 56 51.7999999995
# 82 21.0
# 10 4.2867338848
# Prediction failed for Say You Won't Let Go : James Arthur
# 9 12.8
# 12 2.08557219882
# Prediction failed for Bad And Boujee : Migos Featuring Lil Uzi Vert
# 22 15.432415707
# Prediction failed for Moves : Big Sean
# 18 22.4000000107
# 28 27.7091687282
# 43 20.7704267002
# 67 68.500000015
# 15 16.0
# 99 54.7500000239
# 83 65.9691424208
# Prediction failed for Call On Me : Starley
# 1 1.10010327665
# 21 24.8000000489
# 47 49.6000000069
# 57 72.6000000115
# 84 73.999999991
# 42 27.3538418007
# 36 38.0
# 78 81.749999997
# 25 23.3943650652
# 10
# /home/hrishi/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:7: RuntimeWarning: overflow encountered in exp
# /home/hrishi/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:7: RuntimeWarning: overflow encountered in multiply
